# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd

# %%
import requests

response = requests.get('https://www.timeanddate.com/weather/uk/london/ext')

# %%
soup = BeautifulSoup(response.content, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
# scripts and programs that download content transparent to the user are not allowed without permission
# -->
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    London, England, United Kingdom 14 day weather forecast
#   </title>
#   <meta content="Forecasted weather conditions the coming 2 weeks for London" name="description"/>
#   <meta content="2 weeks, 15 days, 14 days, extended, wether, weather, temp, temps, temperature, celcius, celsius, fahrenheit, sunny, sun, clouds, cloudes, cloudy, windy, forecasts, forecast, met, meterology, metrology, London, England, United Kingdom, W03779, England, eng" name="keywords"/>
#   <meta content="https://www.timeanddate.com/scripts/cityog.php?title=14-Day%20Weather%20Forecast%20for&amp;tint=0x007b7a&amp;city=London&amp;state=England&amp;country=United%20Kingdom&amp;image=london1" property="og:image"/>
#   <meta content="1366" property="og:image:width"/>
# ...

# %%
get_table = soup.find('table', attrs={'class':'tb-wt'})
get_pretty_table = get_table.prettify()

# get_read_table = display_html(get_pretty_table, raw=True)

panda_dataframe = pd.read_html(get_pretty_table)

print(panda_dataframe)

    

# print(get_pretty_table)

# get_table_first_item = get_table[0]

# print(get_table_first_item)

# get_rows = get_table.findChildren(['th', 'tr'])

# print(get_rows)

# for row in get_rows:
#     get_cells = row.findChildren('td')
#     print(get_cells)
#     for cellitem in get_cells:
#         cell_value = cellitem.string
#         print(cell_value)

# for item in get_table.find_all('tr'):
#     print(item)
# Out:
# [                                   Unnamed: 0_level_0  \
#                                                   Day
# 0                                          Wed  9 Dec
# 1                                         Thu  10 Dec
# 2                                         Fri  11 Dec
# 3                                         Sat  12 Dec
# 4                                         Sun  13 Dec
# 5                                         Mon  14 Dec
# 6                                         Tue  15 Dec
# 7                                         Wed  16 Dec
# 8                                         Thu  17 Dec
# 9                                         Fri  18 Dec
# 10                                        Sat  19 Dec
# 11                                        Sun  20 Dec
# 12                                        Mon  21 Dec
# 13                                        Tue  22 Dec
# 14                                        Wed  23 Dec
# ...
